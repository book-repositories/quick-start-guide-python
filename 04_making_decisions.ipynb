# %% [markdown]
# <a href="https://colab.research.google.com/github/michael-borck/just_enough_python/blob/main/04_making_decisions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Making Decisions
#
# Run the code cell below to setup the feeback system. Then move on to the questions.

# %%
# !pip install jupyterquiz > /dev/null 2>&1
# !pip install gofer-grader > /dev/null 2>&1
